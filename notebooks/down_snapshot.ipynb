# %%
from histoplus.helpers.segmentor import CellViTSegmentor

# 20x 에 해당하는 MPP = 0.5로 한 번은 돌려보기
segmentor = CellViTSegmentor.from_histoplus(
    mpp=0.5,   # 20x
    mixed_precision=True,
    inference_image_size=784,
)
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File ~/miniconda3/envs/histoplus/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/miniconda3/envs/histoplus/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/histoplus/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...

# %%
from huggingface_hub import snapshot_download

# %%
import os
os.makedirs("histoplus_offline")

# %%
# snapshot_download(
#     repo_id="Owkin-Bioptimus/histoplus",
#     revision="main",                     # 특정 버전 원하면 commit hash 지정 가능
#     local_dir="/home/sjhong/segmentation/histoplus_offline",       # 오프라인에서 불러올 디렉토리
#     local_dir_use_symlinks=False         # 오프라인 환경에서는 반드시 False 권장
# )

from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="Owkin-Bioptimus/histoplus",
    cache_dir="/home/sjhong/.histoplus/hf_cache",  # 🔥 여기 중요
    local_dir="/home/sjhong/segmentation/histoplus_offline",
    local_dir_use_symlinks=False,
    local_files_only=True,  # 외부 IP 막혀 있으니 필수
)
# Out:
# ---------------------------------------------------------------------------
# LocalEntryNotFoundError                   Traceback (most recent call last)
# Cell In[9], line 10
#       1 # snapshot_download(
#       2 #     repo_id="Owkin-Bioptimus/histoplus",
#       3 #     revision="main",                     # 특정 버전 원하면 commit hash 지정 가능
#       4 #     local_dir="/home/sjhong/segmentation/histoplus_offline",       # 오프라인에서 불러올 디렉토리
#       5 #     local_dir_use_symlinks=False         # 오프라인 환경에서는 반드시 False 권장
#       6 # )
#       8 from huggingface_hub import snapshot_download
# ---> 10 snapshot_download(
#      11     repo_id="Owkin-Bioptimus/histoplus",
#      12     cache_dir="/home/sjhong/.histoplus/hf_cache",  # 🔥 여기 중요
#      13     local_dir="/home/sjhong/segmentation/histoplus_offline",
#      14     local_dir_use_symlinks=False,
#      15     local_files_only=True,  # 외부 IP 막혀 있으니 필수
#      16 )
#
# ...

# %% [markdown]
# ```
# histoplus_offline/
# ├── config.json
# ├── model.safetensors
# ├── preprocessor_config.json
# ├── pytorch_model.bin   (있을 수도 / 없을 수도)
# ├── tokenizer.json
# ├── README.md
# ├── ...
# ```

# %%
from transformers import AutoModel, AutoProcessor

model = AutoModel.from_pretrained(
    "histoplus_offline",
    local_files_only=True
)

processor = AutoProcessor.from_pretrained(
    "histoplus_offline",
    local_files_only=True
)
